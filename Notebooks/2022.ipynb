# %% [markdown]
# # 2022 Data Cleaning

# %%
import pandas as pd
pd.options.display.max_columns = 150
pd.options.display.max_rows = 50

# %%
## Some column names are different for each year.
# We are going to read them separately, them select only the columns that we are going to need for the analysis.
# The rename the columns to match them for all the years.

# %% [markdown]
# ## Columns of interest
# * Country, Education, Languages worked with, Languages want to work with, Developer Type, Salary, SalaryType, Currency, Employment.

# %%
## 2022 Data
df_2022 = pd.read_csv("../Data/RawData/2022/survey_results_public.csv", low_memory=True)
df_2022.iloc[2:4, :]
# Out:
#    ResponseId                                         MainBranch  \
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
#
#                CodingActivities  \
# 2                         Hobby
# 3  I don’t code outside of work
#
#                                            EdLevel  \
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 2  Books / Physical media;Friend or family member...
# 3  Books / Physical media;School (i.e., Universit...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 2  Technical documentation;Blogs;Programming Game...                  NaN
# 3                                                NaN                  NaN
#
#   YearsCode YearsCodePro                                            DevType  \
# 2        14            5  Data scientist or machine learning specialist;...
# 3        20           17                              Developer, full-stack
#
#                 OrgSize      PurchaseInfluence               BuyNewTool  \
# 2    20 to 99 employees  I have some influence                      NaN
# 3  100 to 499 employees  I have some influence  Other (please specify):
#
#                                              Country                 Currency  \
# 2  United Kingdom of Great Britain and Northern I...      GBP\tPound sterling
# 3                                             Israel  ILS\tIsraeli new shekel
#
#    CompTotal CompFreq             LanguageHaveWorkedWith  \
# 2    32000.0   Yearly  C#;C++;HTML/CSS;JavaScript;Python
# 3    60000.0  Monthly       C#;JavaScript;SQL;TypeScript
#
#                   LanguageWantToWorkWith DatabaseHaveWorkedWith  \
# 2  C#;C++;HTML/CSS;JavaScript;TypeScript   Microsoft SQL Server
# 3                      C#;SQL;TypeScript   Microsoft SQL Server
#
#   DatabaseWantToWorkWith PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 2   Microsoft SQL Server                    NaN                    NaN
# 3   Microsoft SQL Server                    NaN                    NaN
#
#   WebframeHaveWorkedWith WebframeWantToWorkWith MiscTechHaveWorkedWith  \
# 2             Angular.js     Angular;Angular.js                 Pandas
# 3  ASP.NET;ASP.NET Core   ASP.NET;ASP.NET Core                    .NET
#
#   MiscTechWantToWorkWith ToolsTechHaveWorkedWith ToolsTechWantToWorkWith  \
# 2                   .NET                     NaN                     NaN
# 3                   .NET                     NaN                     NaN
#
#                  NEWCollabToolsHaveWorkedWith  \
# 2                     Notepad++;Visual Studio
# 3  Notepad++;Visual Studio;Visual Studio Code
#
#                  NEWCollabToolsWantToWorkWith OpSysProfessional use  \
# 2                     Notepad++;Visual Studio               Windows
# 3  Notepad++;Visual Studio;Visual Studio Code               Windows
#
#   OpSysPersonal use VersionControlSystem  \
# 2           Windows                  Git
# 3           Windows                  Git
#
#                                        VCInteraction  VCHostingPersonal use  \
# 2                                        Code editor                    NaN
# 3  Code editor;Command-line;Version control hosti...                    NaN
#
#    VCHostingProfessional use OfficeStackAsyncHaveWorkedWith  \
# 2                        NaN                            NaN
# 3                        NaN    Jira Work Management;Trello
#
#   OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# 2                            NaN               Microsoft Teams
# 3    Jira Work Management;Trello                    Slack;Zoom
#
#   OfficeStackSyncWantToWorkWith        Blockchain  \
# 2               Microsoft Teams  Very unfavorable
# 3                    Slack;Zoom  Very unfavorable
#
#                                           NEWSOSites             SOVisitFreq  \
# 2  Collectives on Stack Overflow;Stack Overflow;S...  Multiple times per day
# 3  Collectives on Stack Overflow;Stack Overflow f...   Daily or almost daily
#
#   SOAccount              SOPartFreq           SOComm              Age Gender  \
# 2       Yes  Multiple times per day          Neutral  25-34 years old    Man
# 3       Yes    A few times per week  Yes, definitely  35-44 years old    Man
#
#   Trans                Sexuality Ethnicity      Accessibility  \
# 2    No                 Bisexual     White  None of the above
# 3    No  Straight / Heterosexual     White  None of the above
#
#                                         MentalHealth TBranch ICorPM  WorkExp  \
# 2  I have a mood or emotional disorder (e.g., dep...      No    NaN      NaN
# 3                                  None of the above      No    NaN      NaN
#
#   Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4 Knowledge_5 Knowledge_6  \
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Knowledge_7 Frequency_1 Frequency_2 Frequency_3 TimeSearching TimeAnswering  \
# 2         NaN         NaN         NaN         NaN           NaN           NaN
# 3         NaN         NaN         NaN         NaN           NaN           NaN
#
#   Onboarding ProfessionalTech TrueFalse_1 TrueFalse_2 TrueFalse_3  \
# 2        NaN              NaN         NaN         NaN         NaN
# 3        NaN              NaN         NaN         NaN         NaN
#
#             SurveyLength                  SurveyEase  ConvertedCompYearly
# 2  Appropriate in length  Neither easy nor difficult              40205.0
# 3  Appropriate in length                        Easy             215232.0

# %%
cols_of_interest2022 = ["Employment", "EdLevel", "DevType", "Country", "Currency", "CompTotal", "CompFreq", "LanguageHaveWorkedWith", "LanguageWantToWorkWith"]
df_2022 = df_2022[cols_of_interest2022]
df_2022.head()
# Out:
#             Employment                                          EdLevel  \
# 0                  NaN                                              NaN
# 1  Employed, full-time                                              NaN
# 2  Employed, full-time  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Employed, full-time     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Employed, full-time     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                              DevType  \
# 0                                                NaN
# 1                                                NaN
# 2  Data scientist or machine learning specialist;...
# 3                              Developer, full-stack
# 4  Developer, front-end;Developer, full-stack;Dev...
#
#                                              Country  \
# 0                                                NaN
# 1                                             Canada
# 2  United Kingdom of Great Britain and Northern I...
# 3                                             Israel
# 4                           United States of America
#
#                     Currency  CompTotal CompFreq  \
# 0                        NaN        NaN      NaN
# 1       CAD\tCanadian dollar        NaN      NaN
# 2        GBP\tPound sterling    32000.0   Yearly
# 3    ILS\tIsraeli new shekel    60000.0  Monthly
# 4  USD\tUnited States dollar        NaN      NaN
#
#                         LanguageHaveWorkedWith  \
# 0                                          NaN
# 1                        JavaScript;TypeScript
# 2            C#;C++;HTML/CSS;JavaScript;Python
# 3                 C#;JavaScript;SQL;TypeScript
# 4  C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#
#                        LanguageWantToWorkWith
# 0                                         NaN
# 1                             Rust;TypeScript
# 2       C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                           C#;SQL;TypeScript
# 4  C#;Elixir;F#;Go;JavaScript;Rust;TypeScript

# %%
df_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Employment              71709 non-null  object
#  1   EdLevel                 71571 non-null  object
#  2   DevType                 61302 non-null  object
#  3   Country                 71771 non-null  object
#  4   Currency                51264 non-null  object
#  5   CompTotal               38422 non-null  float64
#  6   CompFreq                44425 non-null  object
#  7   LanguageHaveWorkedWith  70975 non-null  object
#  8   LanguageWantToWorkWith  67027 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 5.0+ MB

# %% [markdown]
# ## Clean Each column

# %% [markdown]
# ### Extract the Education Level
# * From the EdLevel column, we want only the level of education reached e.g Bachelor's Degree, Master's Degree etc.

# %%
df_2022["EdLevel"] = df_2022["EdLevel"].str.split("(").str[0]

# %%
df_2022["EdLevel"].value_counts()
# Out:
# Bachelor’s degree                                         30276
# Master’s degree                                           15486
# Some college/university study without earning a degree     9326
# Secondary school                                           7904
# Associate degree                                           2236
# Other doctoral degree                                      2169
# Primary/elementary school                                  1806
# Something else                                             1247
# Professional degree                                        1121
# Name: EdLevel, dtype: int64

# %% [markdown]
# ### Convert the DevType column to a list.

# %%
df_2022["DevType"] = df_2022["DevType"].str.split(",")
df_2022.head()
# Out:
#             Employment             EdLevel  \
# 0                  NaN                 NaN
# 1  Employed, full-time                 NaN
# 2  Employed, full-time    Master’s degree
# 3  Employed, full-time  Bachelor’s degree
# 4  Employed, full-time  Bachelor’s degree
#
#                                              DevType  \
# 0                                                NaN
# 1                                                NaN
# 2  [Data scientist or machine learning specialist...
# 3                           [Developer,  full-stack]
# 4  [Developer,  front-end;Developer,  full-stack;...
#
#                                              Country  \
# 0                                                NaN
# 1                                             Canada
# 2  United Kingdom of Great Britain and Northern I...
# 3                                             Israel
# 4                           United States of America
#
#                     Currency  CompTotal CompFreq  \
# 0                        NaN        NaN      NaN
# 1       CAD\tCanadian dollar        NaN      NaN
# 2        GBP\tPound sterling    32000.0   Yearly
# 3    ILS\tIsraeli new shekel    60000.0  Monthly
# 4  USD\tUnited States dollar        NaN      NaN
#
#                         LanguageHaveWorkedWith  \
# 0                                          NaN
# 1                        JavaScript;TypeScript
# 2            C#;C++;HTML/CSS;JavaScript;Python
# 3                 C#;JavaScript;SQL;TypeScript
# 4  C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#
#                        LanguageWantToWorkWith
# 0                                         NaN
# 1                             Rust;TypeScript
# 2       C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                           C#;SQL;TypeScript
# 4  C#;Elixir;F#;Go;JavaScript;Rust;TypeScript

# %% [markdown]
# ### Get the Country currency.
# * Extract the currency for each country from the currency column.

# %%
df_2022["Currency"] = df_2022["Currency"].str.replace("\t", "-").str.split("-").str[0]
df_2022.head()
# Out:
#             Employment             EdLevel  \
# 0                  NaN                 NaN
# 1  Employed, full-time                 NaN
# 2  Employed, full-time    Master’s degree
# 3  Employed, full-time  Bachelor’s degree
# 4  Employed, full-time  Bachelor’s degree
#
#                                              DevType  \
# 0                                                NaN
# 1                                                NaN
# 2  [Data scientist or machine learning specialist...
# 3                           [Developer,  full-stack]
# 4  [Developer,  front-end;Developer,  full-stack;...
#
#                                              Country Currency  CompTotal  \
# 0                                                NaN      NaN        NaN
# 1                                             Canada      CAD        NaN
# 2  United Kingdom of Great Britain and Northern I...      GBP    32000.0
# 3                                             Israel      ILS    60000.0
# 4                           United States of America      USD        NaN
#
#   CompFreq                       LanguageHaveWorkedWith  \
# 0      NaN                                          NaN
# 1      NaN                        JavaScript;TypeScript
# 2   Yearly            C#;C++;HTML/CSS;JavaScript;Python
# 3  Monthly                 C#;JavaScript;SQL;TypeScript
# 4      NaN  C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#
#                        LanguageWantToWorkWith
# 0                                         NaN
# 1                             Rust;TypeScript
# 2       C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                           C#;SQL;TypeScript
# 4  C#;Elixir;F#;Go;JavaScript;Rust;TypeScript

# %% [markdown]
# ### Convert LanguageHaveWorkedWith & LanguageWantToWorkWith to list

# %%
def convert(x):
    try:
        lst = x.split(";")
    except AttributeError:
        pass
    else:
        return lst

# %%
df_2022["LanguageHaveWorkedWith"] = df_2022["LanguageHaveWorkedWith"].apply(convert)
df_2022["LanguageWantToWorkWith"] = df_2022["LanguageWantToWorkWith"].apply(convert)
df_2022.head()
# Out:
#             Employment             EdLevel  \
# 0                  NaN                 NaN
# 1  Employed, full-time                 NaN
# 2  Employed, full-time    Master’s degree
# 3  Employed, full-time  Bachelor’s degree
# 4  Employed, full-time  Bachelor’s degree
#
#                                              DevType  \
# 0                                                NaN
# 1                                                NaN
# 2  [Data scientist or machine learning specialist...
# 3                           [Developer,  full-stack]
# 4  [Developer,  front-end;Developer,  full-stack;...
#
#                                              Country Currency  CompTotal  \
# 0                                                NaN      NaN        NaN
# 1                                             Canada      CAD        NaN
# 2  United Kingdom of Great Britain and Northern I...      GBP    32000.0
# 3                                             Israel      ILS    60000.0
# 4                           United States of America      USD        NaN
#
#   CompFreq                             LanguageHaveWorkedWith  \
# 0      NaN                                               None
# 1      NaN                           [JavaScript, TypeScript]
# 2   Yearly            [C#, C++, HTML/CSS, JavaScript, Python]
# 3  Monthly                  [C#, JavaScript, SQL, TypeScript]
# 4      NaN  [C#, HTML/CSS, JavaScript, SQL, Swift, TypeScr...
#
#                               LanguageWantToWorkWith
# 0                                               None
# 1                                 [Rust, TypeScript]
# 2        [C#, C++, HTML/CSS, JavaScript, TypeScript]
# 3                              [C#, SQL, TypeScript]
# 4  [C#, Elixir, F#, Go, JavaScript, Rust, TypeScr...

# %% [markdown]
# ### Missing Values

# %%
df_2022.isnull().sum()
# Out:
# Employment                 1559
# EdLevel                    1697
# DevType                   11966
# Country                    1497
# Currency                  22004
# CompTotal                 34846
# CompFreq                  28843
# LanguageHaveWorkedWith     2293
# LanguageWantToWorkWith     6241
# dtype: int64

# %%
df_2022.shape
# Out:
# (73268, 9)
